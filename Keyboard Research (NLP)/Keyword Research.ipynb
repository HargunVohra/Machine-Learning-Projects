# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.9.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.0 in c:\users\hargun\anaconda3\lib\site-packages (from pytrends) (2.32.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\hargun\anaconda3\lib\site-packages (from pytrends) (2.2.3)
# Requirement already satisfied: lxml in c:\users\hargun\anaconda3\lib\site-packages (from pytrends) (5.3.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hargun\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hargun\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hargun\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hargun\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hargun\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hargun\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hargun\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hargun\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hargun\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2025.8.3)
# Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2

# %%
import time
import pandas as pd
from pytrends.request import TrendReq

# %%
trends = TrendReq()
trends.build_payload(kw_list = ["Data Science"])
data = trends.interest_by_region()
data
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# Cell In[11], line 2
#       1 trends = TrendReq()
# ----> 2 trends.build_payload(kw_list = ["Data Science"])
#       3 data = trends.interest_by_region()
#       4 data
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:189, in TrendReq.build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     187 self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     188 # get tokens
# --> 189 self._tokens()
#     190 return
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:195, in TrendReq._tokens(self)
#     193 """Makes request to Google to get API tokens for interest over time, interest by region and related queries"""
#     194 # make the request and parse the returned json
# --> 195 widget_dicts = self._get_data(
#     196     url=TrendReq.GENERAL_URL,
#     197     method=TrendReq.POST_METHOD,
#     198     params=self.token_payload,
#     199     trim_chars=4,
#     200 )['widgets']
#     201 # order of the json matters...
#     202 first_region_token = True
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:159, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     157 else:
#     158     if response.status_code == status_codes.codes.too_many_requests:
# --> 159         raise exceptions.TooManyRequestsError.from_response(response)
#     160     raise exceptions.ResponseError.from_response(response)
#
# TooManyRequestsError: The request failed: Google returned a response with code 429

# %%
type(data)

# %%
df = data.sample(50)
df.reset_index().plot(x = "geoName", y = "Data Science", figsize = (10, 5), kind = "bar", color = "orange")
plt.title("Geoname vs Data Science")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = data.sample(50)
#       2 df.reset_index().plot(x = "geoName", y = "Data Science", figsize = (10, 5), kind = "bar", color = "orange")
#       3 plt.title("Geoname vs Data Science")
#
# NameError: name 'data' is not defined

# %%
data = trends.trending_searches(pn = "india")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = trends.trending_searches(pn="india")
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:474, in TrendReq.trending_searches(self, pn)
#     469 """Request data from Google's Hot Searches section and return a dataframe"""
#     471 # make the request
#     472 # forms become obsolete due to the new TRENDING_SEARCHES_URL
#     473 # forms = {'ajax': 1, 'pn': pn, 'htd': '', 'htv': 'l'}
# --> 474 req_json = self._get_data(
#     475     url=TrendReq.TRENDING_SEARCHES_URL,
#     476     method=TrendReq.GET_METHOD
#     477 )[pn]
#     478 result_df = pd.DataFrame(req_json)
#     479 return result_df
#
# File ~\anaconda3\Lib\site-packages\pytrends\request.py:160, in TrendReq._get_data(self, url, method, trim_chars, **kwargs)
#     158 if response.status_code == status_codes.codes.too_many_requests:
#     159     raise exceptions.TooManyRequestsError.from_response(response)
# --> 160 raise exceptions.ResponseError.from_response(response)
#
# ResponseError: The request failed: Google returned a response with code 404

# %%
print(data.head(10))

# %%
keyword = trends.suggestions(keyword = "Programming")
data = pd.DataFrame(keyword)

# %%
print(data.head())
